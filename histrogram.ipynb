# %%
import cv2
import matplotlib.pyplot as plt

img_path = "E:\python\Open cv\Photos\cat.jfif"
img = cv2.imread(img_path)
img = cv2.resize(img,(1280,720))
 
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img)
# Out:
# [[[155 155 155]
#   [155 155 155]
#   [156 156 156]
#   ...
#   [123 122 126]
#   [123 122 126]
#   [123 122 126]]
#
#  [[155 155 155]
#   [155 155 155]
#   [156 156 156]
#   ...
#   [123 122 126]
#   [123 122 126]
#   [123 122 126]]
#
#  [[156 156 156]
#   [156 156 156]
#   [156 156 156]
#   ...
#   [123 122 126]
#   [123 122 126]
#   [123 122 126]]
#
#  ...
#
#  [[180 177 172]
#   [180 177 172]
#   [179 176 171]
#   ...
#   [ 59  56  58]
#   [ 59  56  58]
#   [ 59  56  58]]
#
#  [[180 177 172]
#   [180 176 171]
#   [179 176 171]
#   ...
#   [ 59  56  58]
#   [ 59  56  58]
#   [ 59  56  58]]
#
#  [[180 177 172]
#   [179 176 171]
#   [179 176 171]
#   ...
#   [ 59  56  58]
#   [ 59  56  58]
#   [ 59  56  58]]]

# %%
img.ravel()
# Out:
# array([155, 155, 155, ...,  59,  56,  58], dtype=uint8)

# %%
img.shape
# Out:
# (720, 1280, 3)

# %%
img.ravel().shape
# Out:
# (2764800,)

# %%
img.ravel().size
# Out:
# 2764800

# %%
plt.hist(img.ravel(), bins=256, range = [0,255])
plt.show()

# %%
colors = ('b', 'g', 'r')
img_ravel = [img[:, :, 0].ravel(), img[:, :, 1].ravel(), img[:,:, 2].ravel()] 
plt.hist(img_ravel, color=colors, label=colors)
plt.legend()
plt.show()

# %%
plt.hist(img_ravel, color=colors, label=colors, bins=256, range=[0,256])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 9))
for i, color in enumerate(colors):
    histogram = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(histogram, color=color)
plt.show()

# %%
histogram
# Out:
# array([[0.0000e+00],
#        [2.0000e+00],
#        [2.0000e+00],
#        [6.0000e+00],
#        [4.0000e+00],
#        [1.1000e+01],
#        [1.1000e+01],
#        [3.0000e+01],
#        [2.9000e+01],
#        [4.5000e+01],
#        [3.6000e+01],
#        [3.3000e+01],
#        [3.2000e+01],
#        [4.2000e+01],
#        [4.7000e+01],
#        [3.7000e+01],
#        [4.6000e+01],
#        [4.3000e+01],
#        [8.0000e+01],
#        [6.5000e+01],
#        [6.5000e+01],
#        [8.1000e+01],
#        [9.2000e+01],
#        [9.7000e+01],
#        [1.1900e+02],
#        [1.8000e+02],
#        [2.8900e+02],
#        [1.1480e+03],
#        [1.5450e+03],
#        [1.5260e+03],
#        [1.5030e+03],
#        [1.4060e+03],
#        [1.2440e+03],
#        [1.2860e+03],
#        [1.1790e+03],
#        [1.1720e+03],
#        [1.0760e+03],
#        [1.2750e+03],
#        [1.6500e+03],
#        [1.9700e+03],
#        [1.9020e+03],
#        [2.5730e+03],
#        [2.0680e+03],
#        [2.0390e+03],
#        [2.0000e+03],
#        [2.1970e+03],
#        [2.2200e+03],
#        [2.3130e+03],
#        [2.3880e+03],
#        [2.3760e+03],
#        [2.1490e+03],
#        [2.3180e+03],
#        [2.3100e+03],
#        [2.1760e+03],
#        [1.9480e+03],
#        [1.7490e+03],
#        [1.8950e+03],
#        [1.7410e+03],
#        [1.7470e+03],
#        [1.8650e+03],
#        [1.9060e+03],
#        [2.0580e+03],
#        [1.5870e+03],
#        [1.4320e+03],
#        [1.4260e+03],
#        [1.3380e+03],
#        [1.2720e+03],
#        [1.2260e+03],
#        [1.2440e+03],
#        [1.1990e+03],
#        [1.2130e+03],
#        [1.2170e+03],
#        [1.2910e+03],
#        [1.2170e+03],
#        [1.2960e+03],
#        [1.3170e+03],
#        [1.4200e+03],
#        [1.5500e+03],
#        [1.7320e+03],
#        [2.6640e+03],
#        [3.1620e+03],
#        [2.7950e+03],
#        [2.4360e+03],
#        [2.2470e+03],
#        [2.2660e+03],
#        [2.4190e+03],
#        [2.2540e+03],
#        [2.1530e+03],
#        [1.9440e+03],
#        [1.6260e+03],
#        [1.6530e+03],
#        [1.6680e+03],
#        [1.7460e+03],
#        [1.6350e+03],
#        [1.5090e+03],
#        [1.6400e+03],
#        [1.3870e+03],
#        [1.3810e+03],
#        [1.3220e+03],
#        [1.3740e+03],
#        [1.3840e+03],
#        [1.3570e+03],
#        [1.4150e+03],
#        [1.4870e+03],
#        [1.3860e+03],
#        [1.5420e+03],
#        [1.5910e+03],
#        [2.0340e+03],
#        [1.7680e+03],
#        [1.8380e+03],
#        [1.7350e+03],
#        [1.7690e+03],
#        [1.6300e+03],
#        [1.5660e+03],
#        [1.4220e+03],
#        [1.5720e+03],
#        [1.4560e+03],
#        [1.6350e+03],
#        [1.7690e+03],
#        [1.8450e+03],
#        [2.2730e+03],
#        [2.5890e+03],
#        [2.9800e+03],
#        [3.3560e+03],
#        [3.4220e+03],
#        [3.5340e+03],
#        [4.2040e+03],
#        [4.4170e+03],
#        [4.3030e+03],
#        [4.9780e+03],
#        [5.2040e+03],
#        [5.0120e+03],
#        [5.1620e+03],
#        [4.8980e+03],
#        [4.9460e+03],
#        [5.0190e+03],
#        [4.8880e+03],
#        [5.1430e+03],
#        [5.1030e+03],
#        [5.5470e+03],
#        [5.4210e+03],
#        [6.1630e+03],
#        [6.6210e+03],
#        [6.8560e+03],
#        [6.9880e+03],
#        [7.7290e+03],
#        [8.8650e+03],
#        [9.4460e+03],
#        [9.5260e+03],
#        [1.0266e+04],
#        [1.1180e+04],
#        [1.1576e+04],
#        [1.1359e+04],
#        [1.3215e+04],
#        [1.3764e+04],
#        [1.1341e+04],
#        [1.1456e+04],
#        [1.1857e+04],
#        [1.0730e+04],
#        [1.0240e+04],
#        [1.0684e+04],
#        [9.7510e+03],
#        [9.0840e+03],
#        [8.3860e+03],
#        [7.9160e+03],
#        [7.8570e+03],
#        [8.3960e+03],
#        [9.7350e+03],
#        [9.4110e+03],
#        [9.6180e+03],
#        [9.8490e+03],
#        [1.0045e+04],
#        [9.6860e+03],
#        [9.2820e+03],
#        [8.8930e+03],
#        [8.4130e+03],
#        [8.4310e+03],
#        [8.4020e+03],
#        [9.1080e+03],
#        [8.0130e+03],
#        [7.7150e+03],
#        [7.7310e+03],
#        [7.7090e+03],
#        [7.9100e+03],
#        [7.7750e+03],
#        [7.7950e+03],
#        [8.0750e+03],
#        [8.5010e+03],
#        [8.4020e+03],
#        [8.9090e+03],
#        [9.3840e+03],
#        [9.9440e+03],
#        [1.0152e+04],
#        [9.1030e+03],
#        [7.9330e+03],
#        [7.8260e+03],
#        [7.4640e+03],
#        [5.7500e+03],
#        [4.8410e+03],
#        [5.6930e+03],
#        [5.5490e+03],
#        [5.6570e+03],
#        [4.9630e+03],
#        [4.0430e+03],
#        [2.2460e+03],
#        [2.0230e+03],
#        [2.0040e+03],
#        [2.1340e+03],
#        [2.0880e+03],
#        [2.1260e+03],
#        [2.2330e+03],
#        [2.1930e+03],
#        [2.1370e+03],
#        [2.2710e+03],
#        [2.3540e+03],
#        [2.2960e+03],
#        [2.3610e+03],
#        [2.4930e+03],
#        [2.3960e+03],
#        [2.3810e+03],
#        [2.4800e+03],
#        [2.5200e+03],
#        [2.6950e+03],
#        [2.5740e+03],
#        [2.5540e+03],
#        [2.8570e+03],
#        [2.8480e+03],
#        [2.8500e+03],
#        [3.5000e+03],
#        [3.8350e+03],
#        [3.6360e+03],
#        [3.7170e+03],
#        [3.4040e+03],
#        [3.1320e+03],
#        [3.1130e+03],
#        [2.9230e+03],
#        [3.3230e+03],
#        [4.3060e+03],
#        [3.8780e+03],
#        [3.5760e+03],
#        [2.2980e+03],
#        [1.8960e+03],
#        [2.0070e+03],
#        [2.2820e+03],
#        [2.0070e+03],
#        [1.2170e+03],
#        [1.1180e+03],
#        [1.1180e+03],
#        [1.7030e+03],
#        [1.3910e+03],
#        [1.1690e+03],
#        [6.6700e+02],
#        [8.0000e+00],
#        [0.0000e+00],
#        [0.0000e+00],
#        [0.0000e+00]], dtype=float32)
